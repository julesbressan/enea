# %%
import pandas as pd 
from config import *

# %%
raw_df = pd.read_csv(CFG.data_rootfolder / "ACCIDENT_LOCATION.csv")
df = raw_df
raw_df.head(20)
# Out:
#      ACCIDENT_NO  NODE_ID  ROAD_ROUTE_1                          ROAD_NAME  \
# 0   T20060000010    43078        2090.0                             FOSTER
# 1   T20060000018    29720        5057.0                             HALLAM
# 2   T20060000022   203074        9999.0                             BROWNS
# 3   T20060000023    55462        2400.0                         SPRINGVALE
# 4   T20060000026   202988        9999.0                          ELIZABETH
# 5   T20060000028   277431        9999.0                           BUNGOWER
# 6   T20060000035   203045        5594.0                            PRINCES
# 7   T20060000042   203047        5765.0                         CRANBOURNE
# 8   T20060000044    35621        2090.0                FRANKSTON-DANDENONG
# 9   T20060000046   205206        9999.0                            STATION
# 10  T20060000047   203077        2050.0                         CHELTENHAM
# ...

# %%
df = df[["ACCIDENT_NO","ROAD_TYPE"]].set_index("ACCIDENT_NO",verify_integrity= "ACCIDENT_NO")
df
# Out:
#              ROAD_TYPE
# ACCIDENT_NO
# T20060000010    STREET
# T20060000018      ROAD
# T20060000022      ROAD
# T20060000023      ROAD
# T20060000026    AVENUE
# ...                ...
# T20200019239    AVENUE
# T20200019247      ROAD
# T20200019250      ROAD
# T20200019253   HIGHWAY
# T20200019417      ROAD
#
# [203708 rows x 1 columns]
